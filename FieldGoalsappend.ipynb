# %%
FgPct_A = []
FgMade1_19_A = []
FgAtt1_19_A = []
Fg1_19Pct_A = []
FgMade20_29_A = []   
FgAtt20_29_A = []
Fg20_29Pct_A = []
FgMade30_39_A = []
FgAtt30_39_A = []
Fg30_39Pct_A = []
FgMade40_49_A = []
FgAtt40_49_A = []
Fg40_49Pct_A = []
FgMade50Plus_A = []
FgAtt50Plus_A = []
Fg50PlusPct_A = []
FgPct_H = []
FgMade1_19_H = []
FgAtt1_19_H = []
Fg1_19Pct_H = []
FgMade20_29_H = []
FgAtt20_29_H = []
Fg20_29Pct_H = []
FgMade30_39_H = []
FgAtt30_39_H = []
Fg30_39Pct_H = []
FgMade40_49_H = []
FgAtt40_49_H = []
Fg40_49Pct_H = []
FgMade50Plus_H = []
FgAtt50Plus_H = []
Fg50PlusPct_H = []

# %%
for game in week1gameurls:   
    time.sleep(5)
    print(f"Now Processing: {game}")
    try:
        boxresponse = requests.get(
                        url=f"https://api.mysportsfeeds.com/v1.2/pull/nfl/2018-regular/game_boxscore.json?gameid={game}",
                        headers={
                            "Authorization": "Basic " + base64.b64encode('{}:{}'.format("caa67d28-e6d3-4fae-8919-10331e","password").encode('utf-8')).decode('ascii')
                        }).json()

        boxFgPct_A = float(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgPct"].get("#text", 0))
        boxFgMade1_19_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgMade1_19"].get("#text", 0))
        boxFgAtt1_19_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgAtt1_19"].get("#text", 0))
        boxFg1_19Pct_A = float(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["Fg1_19Pct"].get("#text", 0))
        boxFgMade20_29_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgMade20_29"].get("#text", 0))
        boxFgAtt20_29_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgAtt20_29"].get("#text", 0))
        boxFg20_29Pct_A = float(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["Fg20_29Pct"].get("#text", 0))
        boxFgMade30_39_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgMade30_39"].get("#text", 0))
        boxFgAtt30_39_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgAtt30_39"].get("#text", 0))
        boxFg30_39Pct_A = float(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["Fg30_39Pct"].get("#text", 0))
        boxFgMade40_49_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgMade40_49"].get("#text", 0))
        boxFgAtt40_49_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgAtt40_49"].get("#text", 0))
        boxFg40_49Pct_A = float(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["Fg40_49Pct"].get("#text", 0))
        boxFgMade50Plus_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgMade50Plus"].get("#text", 0))
        boxFgAtt50Plus_A = int(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["FgAtt50Plus"].get("#text", 0))
        boxFg50PlusPct_A = float(boxresponse["gameboxscore"]["awayTeam"]["awayTeamStats"]["Fg50PlusPct"].get("#text", 0))
        boxFgPct_H = float(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgPct"].get("#text", 0))
        boxFgMade1_19_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgMade1_19"].get("#text", 0))
        boxFgAtt1_19_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgAtt1_19"].get("#text", 0))
        boxFg1_19Pct_H = float(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["Fg1_19Pct"].get("#text", 0))
        boxFgMade20_29_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgMade20_29"].get("#text", 0))
        boxFgAtt20_29_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgAtt20_29"].get("#text", 0))
        boxFg20_29Pct_H = float(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["Fg20_29Pct"].get("#text", 0))
        boxFgMade30_39_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgMade30_39"].get("#text", 0))
        boxFgAtt30_39_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgAtt30_39"].get("#text", 0))
        boxFg30_39Pct_H = float(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["Fg30_39Pct"].get("#text", 0))
        boxFgMade40_49_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgMade40_49"].get("#text", 0))
        boxFgAtt40_49_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgAtt40_49"].get("#text", 0))
        boxFg40_49Pct_H = float(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["Fg40_49Pct"].get("#text", 0))
        boxFgMade50Plus_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgMade50Plus"].get("#text", 0))
        boxFgAtt50Plus_H = int(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["FgAtt50Plus"].get("#text", 0))
        boxFg50PlusPct_H = float(boxresponse["gameboxscore"]["homeTeam"]["homeTeamStats"]["Fg50PlusPct"].get("#text", 0))  
        
        FgPct_A.append(boxFgPct_A)
        FgMade1_19_A.append(boxFgMade1_19_A)
        FgAtt1_19_A.append(boxFgAtt1_19_A)
        Fg1_19Pct_A.append(boxFg1_19Pct_A)
        FgMade20_29_A.append(boxFgMade20_29_A)  
        FgAtt20_29_A.append(boxFgAtt20_29_A)
        Fg20_29Pct_A.append(boxFg20_29Pct_A)
        FgMade30_39_A.append(boxFgMade30_39_A)
        FgAtt30_39_A.append(boxFgAtt30_39_A)
        Fg30_39Pct_A.append(boxFg30_39Pct_A)
        FgMade40_49_A.append(boxFgMade40_49_A)
        FgAtt40_49_A.append(boxFgAtt40_49_A)
        Fg40_49Pct_A.append(boxFg40_49Pct_A)
        FgMade50Plus_A.append(boxFgMade50Plus_A)
        FgAtt50Plus_A.append(boxFgAtt50Plus_A)
        Fg50PlusPct_A.append(boxFg50PlusPct_A)
        FgPct_H.append(boxFgPct_H)     
        FgMade1_19_H.append(boxFgMade1_19_H)
        FgAtt1_19_H.append(boxFgAtt1_19_H)
        Fg1_19Pct_H.append(boxFg1_19Pct_H)
        FgMade20_29_H.append(boxFgMade20_29_H)
        FgAtt20_29_H.append(boxFgAtt20_29_H)
        Fg20_29Pct_H.append(boxFg20_29Pct_H)
        FgMade30_39_H.append(boxFgMade30_39_H)
        FgAtt30_39_H.append(boxFgAtt30_39_H)
        Fg30_39Pct_H.append(boxFg30_39Pct_H)
        FgMade40_49_H.append(boxFgMade40_49_H)
        FgAtt40_49_H.append(boxFgAtt40_49_H)
        Fg40_49Pct_H.append(boxFg40_49Pct_H)
        FgMade50Plus_H.append(boxFgMade50Plus_H)
        FgAtt50Plus_H.append(boxFgAtt50Plus_H)
        Fg50PlusPct_H.append(boxFg50PlusPct_H)      
    except:
        print("Error occured")
