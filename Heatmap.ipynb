# %%
import gmaps
import numpy as np
import pandas as pd

# %%
gkey = "AIzaSyDkwm-MsLDHq79iRGf9BX5mXQ7xKOHNY6s"

# %%
df = pd.read_csv("GameResultsLatsLongs.csv")
df.head()
# Out:
#    Game ID  Week        Date Time (EST)                 Location Home Team  \
# 0    45944     1  2018-09-06     8:20PM  Lincoln Financial Field       PHI
# 1    45945     1  2018-09-09     1:00PM         M&T Bank Stadium       BAL
# 2    45946     1  2018-09-09     1:00PM        Lucas Oil Stadium       IND
# 3    45947     1  2018-09-09     1:00PM         Gillette Stadium        NE
# 4    45948     1  2018-09-09     1:00PM          MetLife Stadium       NYG
#
#   Away Team  Home Score  Away Score  Total Points    ...      Away QB Rating  \
# 0       ATL          18          12            30    ...                57.4
# 1       BUF          47           3            50    ...                17.1
# 2       CIN          23          34            57    ...               109.7
# 3       HOU          27          20            47    ...                62.9
# 4       JAX          15          20            35    ...                67.2
#
#    Away Passing TDs  Away Interceptions  Away First Downs  Away FG Attempts  \
# 0                 0                   1                16                 2
# 1                 0                   2                10                 2
# 2                 2                   1                19                 2
# 3                 1                   1                21                 2
# 4                 1                   1                17                 2
#
#    Away FG Made  Away Punts  Indoor        Lat        Lng
# 0             2           6   False  39.900833 -75.167500
# 1             1           8   False  39.278056 -76.622778
# 2             2           2    True  39.760056 -86.163806
# 3             2           6   False  42.090944 -71.264344
# 4             2           7   False  40.813528 -74.074361
#
# [5 rows x 48 columns]

# %%
locations = df[["Lat", "Lng"]].astype(float)

# %%
scoring = df["Total Points"].astype(float)

# %%
gmaps.configure(api_key=gkey)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=scoring*.3, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 100)
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = .5
# Out:
# Figure(layout=FigureLayout(height='420px'))
